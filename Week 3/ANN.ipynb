# %%
import numpy as np
def sigmoid(x):
    return 1/(1+np.exp(-x))

def sigmoid_derivative(x):
    return x * (1-x)

X = np.random.randint(0, 2, size=(100, 2)) #Years of experience
y = ((X[:, 0] & X[:, 1])).reshape(-1, 1) #Performance rating

#weight assign
np.random.seed(1)
weights_input_hidden = np.random.rand(2,2)
weights_output_hidden = np.random.rand(2,1)

#bias assign
bias_hidden = np.zeros((1,2))
bias_output = np.zeros((1,1))

learning_rate = 0.1
epochs = 5000
n = X.shape[0]


for epoch in range(epochs):
    hidden_input= X.dot(weights_input_hidden) + bias_hidden
    hidden_output = sigmoid(hidden_input)

    final_input = hidden_output.dot(weights_output_hidden) + bias_output
    final_output = sigmoid(final_input)

    error = y - final_output
    d_output = error * sigmoid_derivative (final_output)
    d_hidden = d_output.dot(weights_output_hidden.T) * sigmoid_derivative(hidden_output) #T significes tranpose

    #weight update
    weights_output_hidden += hidden_output.T.dot(d_output) * learning_rate
    bias_output += np.sum(d_output,axis = 0, keepdims=True) * learning_rate

    if epoch % 1000 == 0:
        loss = np.mean(np.square(error))
        print(f"Epoch {epoch}, Loss:{loss:.4f}")


print("Prediction after training")
for i, inputs in enumerate(X):
    hidden_output = sigmoid(np.dot(inputs, weights_input_hidden) + bias_hidden)
    final_output = sigmoid(np.dot(hidden_output, weights_output_hidden) + bias_output)
    print(f"{inputs} -> {final_output[0][0]:.3f} (Target: {y[i][0]})")
# Out:
# Epoch 0, Loss:0.2647
# Epoch 1000, Loss:0.0658
# Epoch 2000, Loss:0.0447
# Epoch 3000, Loss:0.0331
# Epoch 4000, Loss:0.0259
# Prediction after training
# [0 1] -> 0.008 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 1] -> 0.805 (Target: 1)
# [1 1] -> 0.805 (Target: 1)
# [0 1] -> 0.008 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 1] -> 0.805 (Target: 1)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [0 0] -> 0.000 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [0 1] -> 0.008 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [0 1] -> 0.008 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 1] -> 0.805 (Target: 1)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 1] -> 0.805 (Target: 1)
# [0 1] -> 0.008 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [0 1] -> 0.008 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 0] -> 0.211 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 1] -> 0.008 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [0 0] -> 0.000 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [1 0] -> 0.211 (Target: 0)
# [1 1] -> 0.805 (Target: 1)
# [0 0] -> 0.000 (Target: 0)

# %% [markdown]
# ### Multilayer Tensorflow

# %%
import numpy as np
from tensorflow.keras import layers, models
import pandas as pd

# %%
df = pd.read_csv("loan_synthetic_data.csv")
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  income_normalized  credit_normalized  approval
# 0                0           0           0.374540           0.261706         0
# 1                1           1           0.950714           0.246979         0
# 2                2           2           0.731994           0.906255         1
# 3                3           3           0.598658           0.249546         1
# 4                4           4           0.156019           0.271950         1
# ...            ...         ...                ...                ...       ...
# 1995          1995        1995           0.656955           0.442107         0
# 1996          1996        1996           0.956615           0.334401         1
# 1997          1997        1997           0.068958           0.394572         0
# 1998          1998        1998           0.057055           0.529941         0
# 1999          1999        1999           0.282187           0.161367         1
#
# [2000 rows x 5 columns]

# %%
X = df[["income_normalized", "credit_normalized"]].values.astype("float32")
y = df["approval"].values.astype("float32")

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
model = models.Sequential([
    layers.Dense(8, activation="relu", input_shape=(2,)),
    layers.Dense(4, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
# Out:
# d:\Training\.venv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5813 - loss: 0.6774 - val_accuracy: 0.6000 - val_loss: 0.6672
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5813 - loss: 0.6702 - val_accuracy: 0.6000 - val_loss: 0.6594
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5813 - loss: 0.6648 - val_accuracy: 0.6000 - val_loss: 0.6539
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5813 - loss: 0.6604 - val_accuracy: 0.6000 - val_loss: 0.6493
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5813 - loss: 0.6561 - val_accuracy: 0.6000 - val_loss: 0.6449
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5813 - loss: 0.6511 - val_accuracy: 0.6000 - val_loss: 0.6398
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5813 - loss: 0.6447 - val_accuracy: 0.6000 - val_loss: 0.6338
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5867 - loss: 0.6371 - val_accuracy: 0.6125 - val_loss: 0.6271
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6094 - loss: 0.6290 - val_accuracy: 0.6344 - val_loss: 0.6203
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6266 - loss: 0.6212 - val_accuracy: 0.6500 - val_loss: 0.6141
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6406 - loss: 0.6134 - val_accuracy: 0.6562 - val_loss: 0.6078
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6547 - loss: 0.6051 - val_accuracy: 0.6594 - val_loss: 0.6019
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6750 - loss: 0.5979 - val_accuracy: 0.6687 - val_loss: 0.5972
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6891 - loss: 0.5921 - val_accuracy: 0.6812 - val_loss: 0.5932
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7008 - loss: 0.5872 - val_accuracy: 0.6906 - val_loss: 0.5897
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7055 - loss: 0.5828 - val_accuracy: 0.7125 - val_loss: 0.5867
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7125 - loss: 0.5791 - val_accuracy: 0.7156 - val_loss: 0.5840
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7164 - loss: 0.5758 - val_accuracy: 0.7188 - val_loss: 0.5816
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7234 - loss: 0.5728 - val_accuracy: 0.7156 - val_loss: 0.5794
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7227 - loss: 0.5701 - val_accuracy: 0.7188 - val_loss: 0.5775
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7266 - loss: 0.5677 - val_accuracy: 0.7125 - val_loss: 0.5757
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7258 - loss: 0.5655 - val_accuracy: 0.7063 - val_loss: 0.5740
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7273 - loss: 0.5635 - val_accuracy: 0.7125 - val_loss: 0.5725
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7266 - loss: 0.5616 - val_accuracy: 0.7125 - val_loss: 0.5711
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7320 - loss: 0.5599 - val_accuracy: 0.7031 - val_loss: 0.5698
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7328 - loss: 0.5584 - val_accuracy: 0.7000 - val_loss: 0.5687
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7320 - loss: 0.5570 - val_accuracy: 0.7000 - val_loss: 0.5676
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7336 - loss: 0.5556 - val_accuracy: 0.7063 - val_loss: 0.5667
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7375 - loss: 0.5544 - val_accuracy: 0.7094 - val_loss: 0.5658
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7391 - loss: 0.5533 - val_accuracy: 0.7063 - val_loss: 0.5649

# %%
loss, acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {acc:.3f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7350 - loss: 0.5493
# Test Accuracy: 0.735

# %%
preds = model.predict(X_test[:10])
for i in range(10):
    print(f"Income={X_test[i][0]:.2f}, Credit={X_test[i][1]:.2f} -> Prob={preds[i][0]:.3f}, Label={y_test[i]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Income=0.19, Credit=0.14 -> Prob=0.396, Label=0.0
# Income=0.32, Credit=0.57 -> Prob=0.595, Label=1.0
# Income=0.23, Credit=0.19 -> Prob=0.396, Label=1.0
# Income=0.35, Credit=0.28 -> Prob=0.396, Label=0.0
# Income=0.07, Credit=0.22 -> Prob=0.396, Label=1.0
# Income=0.52, Credit=0.18 -> Prob=0.397, Label=0.0
# Income=0.07, Credit=0.83 -> Prob=0.648, Label=0.0
# Income=0.80, Credit=0.29 -> Prob=0.597, Label=0.0
# Income=0.23, Credit=0.93 -> Prob=0.771, Label=1.0
# Income=0.54, Credit=0.97 -> Prob=0.886, Label=1.0
